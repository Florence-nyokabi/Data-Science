# %%
import pandas as pd
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt

# %%
cancer_df=pd.read_csv('./Downloads/cancer-patients.csv')

# %%
cancer_df.head(8)
# Out:
#    index Patient Id  Age  Patient’s age  Gender  Air Pollution  Alcohol use  \
# 0      0         P1   33              2       1              2            4
# 1      1        P10   17              0       1              3            1
# 2      2       P100   35              2       1              4            5
# 3      3      P1000   37              2       1              7            7
# 4      4       P101   46              5       1              6            8
# 5      5       P102   35              2       1              4            5
# 6      6       P103   52              5       2              2            4
# 7      7       P104   28              1       2              3            1
#
#    Dust Allergy  OccuPational Hazards  Genetic Risk  ...  Weight Loss  \
# 0             5                     4             3  ...            4
# 1             5                     3             4  ...            3
# 2             6                     5             5  ...            7
# ...

# %%
cancer_df.dtypes
# Out:
# index                        int64
# Patient Id                  object
# Age                          int64
# Patient’s age                int64
# Gender                       int64
# Air Pollution                int64
# Alcohol use                  int64
# Dust Allergy                 int64
# OccuPational Hazards         int64
# Genetic Risk                 int64
# chronic Lung Disease         int64
# Balanced Diet                int64
# Obesity                      int64
# Smoking                      int64
# Passive Smoker               int64
# Chest Pain                   int64
# Coughing of Blood            int64
# Fatigue                      int64
# Weight Loss                  int64
# Shortness of Breath          int64
# Wheezing                     int64
# Swallowing Difficulty        int64
# Clubbing of Finger Nails     int64
# Frequent Cold                int64
# Dry Cough                    int64
# Snoring                      int64
# Level                       object
# ...

# %%
columns_to_drop=['Patient Id', 'Age', 'Level', 'Fatigue', 'Swallowing Difficulty', 'Snoring', 'Dry Cough', 'Frequent Cold', 'Wheezing', 'Obesity', 'Passive Smoker', 'Clubbing of Finger Nails', 'Weight Loss','Weight Loss','Coughing of Blood']

# %%
cancer_df=cancer_df.drop(columns_to_drop, axis=1)

# %%
cancer_df.head(10)
# Out:
#    index  Patient’s age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0      0              2       1              2            4             5
# 1      1              0       1              3            1             5
# 2      2              2       1              4            5             6
# 3      3              2       1              7            7             7
# 4      4              5       1              6            8             7
# 5      5              2       1              4            5             6
# 6      6              5       2              2            4             5
# 7      7              1       2              3            1             4
# 8      8              2       2              4            5             6
# 9      9              5       1              2            3             4
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 0                     4             3                     2              2
# ...

# %%
cancer_df.fillna(0)
# Out:
#      index  Patient’s age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0        0              2       1              2            4             5
# 1        1              0       1              3            1             5
# 2        2              2       1              4            5             6
# 3        3              2       1              7            7             7
# 4        4              5       1              6            8             7
# ..     ...            ...     ...            ...          ...           ...
# 995    995              5       1              6            7             7
# 996    996              2       2              6            8             7
# 997    997              1       2              4            5             6
# 998    998              1       2              6            8             7
# 999    999              5       1              6            5             6
#
# ...

# %%
cancer_df['Cancer Level'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cancer Level'>

# %%
corr_matrix = cancer_df.corr()

# %%
sns.heatmap(corr_matrix, cmap='coolwarm', annot=True)
# Out:
# <Axes: >

# %%
Y=cancer_df['Cancer Level']

# %%
Y
# Out:
# 0      0
# 1      1
# 2      2
# 3      2
# 4      2
#       ..
# 995    2
# 996    2
# 997    2
# 998    2
# 999    2
# Name: Cancer Level, Length: 1000, dtype: int64

# %%
X=cancer_df.drop('Cancer Level', axis=1)

# %%
X
# Out:
#      index  Patient’s age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0        0              2       1              2            4             5
# 1        1              0       1              3            1             5
# 2        2              2       1              4            5             6
# 3        3              2       1              7            7             7
# 4        4              5       1              6            8             7
# ..     ...            ...     ...            ...          ...           ...
# 995    995              5       1              6            7             7
# 996    996              2       2              6            8             7
# 997    997              1       2              4            5             6
# 998    998              1       2              6            8             7
# 999    999              5       1              6            5             6
#
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
X_train, X_test, Y_train, Y_test=train_test_split(X,Y, test_size=0.3, random_state=101)

# %%
log_model = LogisticRegression(solver='lbfgs', max_iter=1000)

# %%
log_model=LogisticRegression(solver='liblinear')

# %%
log_model.fit(X_train, Y_train)
# Out:
# LogisticRegression(solver='liblinear')

# %%
predict=log_model.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(Y_test,predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.72      0.76        93
#            1       0.78      0.80      0.79       109
#            2       0.93      1.00      0.97        98
#
#     accuracy                           0.84       300
#    macro avg       0.84      0.84      0.84       300
# weighted avg       0.84      0.84      0.84       300
